# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import csv
from datetime import timedelta
import statsmodels.api as sm
import os
import matplotlib.dates as mdates

# %%
#print(os.getcwd())
#print(os.listdir())

os.chdir('C:\\Users\\jonat\\football_stats')
# Out:
# C:\Users\jonat
# ['.azuredatastudio', '.bash_history', '.boto', '.conda', '.condarc', '.continuum', '.gitconfig', '.gsutil', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.ssh', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Dividend_Capture_Strategy_Analysis', 'Documents', 'Downloads', 'Favorites', 'football_stats', 'gcloud', 'Insurance Portfolio Project.ipynb', 'IntelGraphicsProfiles', 'Library', 'Links', 'Local Settings', 'Microsoft', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{9e427b32-6b52-11ed-9116-dbbe238d97a1}.TM.blf', 'NTUSER.DAT{9e427b32-6b52-11ed-9116-dbbe238d97a1}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{9e427b32-6b52-11ed-9116-dbbe238d97a1}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'source', 'ssh', 'Start Menu', 'Templates', 'Tracing', 'Videos']

# %%
#player_valuations = pd.read_csv("player_valuations.csv")

players = pd.read_csv("players.csv")

transfers = pd.read_csv("transfers.csv")

# %%
#print(player_valuations.head(50))

print(players.head(10))

print(transfers.head(10))
# Out:
#    player_id first_name     last_name                 name  last_season  \
# 0         10   Miroslav         Klose       Miroslav Klose         2015
# 1         26      Roman  Weidenfeller   Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov     Dimitar Berbatov         2015
# 3         77        NaN         Lúcio                Lúcio         2012
# 4         80        Tom        Starke           Tom Starke         2017
# 5        109        NaN          Dedê                 Dedê         2013
# 6        123  Christoph     Metzelder  Christoph Metzelder         2012
# 7        132      Tomas       Rosicky        Tomas Rosicky         2015
# 8        162       Marc       Ziegler         Marc Ziegler         2012
# 9        215      Roque    Santa Cruz     Roque Santa Cruz         2015
#
#    current_club_id          player_code    country_of_birth   city_of_birth  \
# 0              398       miroslav-klose              Poland           Opole
# ...

# %%
# Organize data

players = players[['player_id', 'name', 'last_season', 'current_club_id', 'player_code', 
                   'country_of_birth','country_of_citizenship', 'date_of_birth', 'sub_position', 
                   'position', 'contract_expiration_date', 'current_club_domestic_competition_id',
                   'current_club_name', 'market_value_in_eur','highest_market_value_in_eur']]

players = players.dropna(subset=["market_value_in_eur"])

print(players)
# Out:
#        player_id                name  last_season  current_club_id  \
# 0             10      Miroslav Klose         2015              398
# 1             26  Roman Weidenfeller         2017               16
# 2             65    Dimitar Berbatov         2015             1091
# 3             77               Lúcio         2012              506
# 4             80          Tom Starke         2017               27
# ...          ...                 ...          ...              ...
# 31531    1230202       Borja Vázquez         2023             2687
# 31538    1237999      Samuel Obinaya         2023            55686
# 31540    1240467  Artem Prysyazhnyuk         2023             6992
# 31542    1240762    Araphat Mohammed         2023             2778
# 31548    1247360        Ivan M'Bahia         2023             3524
#
#               player_code    country_of_birth country_of_citizenship  \
# 0          miroslav-klose              Poland                Germany
# ...

# %%
transfers = transfers.dropna(subset=["transfer_fee"])

transfers = transfers[transfers['transfer_fee'] != 0]

##print(transfers)

merged = pd.merge(players,transfers, on = "player_id", how = "right")

merged = merged.groupby(["country_of_birth", "transfer_season"])["transfer_fee"].mean()
print(merged)
# Out:
# country_of_birth  transfer_season
# Albania           09/10              5.000000e+04
#                   12/13              9.000000e+04
#                   13/14              3.100000e+04
#                   14/15              1.000000e+05
#                   15/16              2.283333e+06
#                                          ...
# Zimbabwe          19/20              1.200000e+07
#                   21/22              7.600000e+05
#                   22/23              1.000000e+05
#                   23/24              2.200000e+06
#                   24/25              4.000000e+06
# Name: transfer_fee, Length: 1129, dtype: float64
